# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abdallah Ashraf Ahmed Sadek**
#
# data scientist

# %% [markdown]
# *I am interested in data science because it can make you understands a lot of things*.

# %% [markdown]
# ### the below line calculate 1 + 1

# %%
1+1
# Out:
# 2

# %% [markdown]
# - unordered list
# ***
# 1. ordered list
